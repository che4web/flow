# %%
import  matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
def contur_plot(name,C0=0):
    fig, ax = plt.subplots(figsize=(8, 4))
    data= np.genfromtxt(name)
    NY=32
    NX=(NY-1)*2+1
    
    z = data.T[2].reshape((NY, NX))
    z-=C0
    x = np.linspace(0, 2.0, NX)
    y = np.linspace(0, 1.0, NY)

    X, Y = np.meshgrid(x, y)  
    cs = ax.contourf(X, Y, z,cmap=plt.cm.rainbow)
    
    cbar = fig.colorbar(cs)
    return z
    # fig.savefig(name+".png")
    #fig.clf()

# %%
z = contur_plot('c.txt')

# %%
contur_plot('t.txt')
# Out:
# array([[1.      , 1.      , 1.      , ..., 1.      , 1.      , 1.      ],
#        [0.9794  , 0.978883, 0.978197, ..., 0.979677, 0.9794  , 0.978883],
#        [0.958988, 0.95793 , 0.956551, ..., 0.959543, 0.958988, 0.95793 ],
#        ...,
#        [0.111108, 0.109577, 0.107929, ..., 0.112101, 0.111108, 0.109577],
#        [0.055521, 0.054784, 0.053968, ..., 0.056013, 0.055521, 0.054784],
#        [0.      , 0.      , 0.      , ..., 0.      , 0.      , 0.      ]])

# %%
contur_plot('psi.txt')
# Out:
# array([[0.      , 0.      , 0.      , ..., 0.      , 0.      , 0.      ],
#        [0.00911 , 0.010179, 0.011234, ..., 0.006633, 0.00911 , 0.010179],
#        [0.032582, 0.03672 , 0.040754, ..., 0.023901, 0.032582, 0.03672 ],
#        ...,
#        [0.029552, 0.034373, 0.039186, ..., 0.019677, 0.029552, 0.034373],
#        [0.007109, 0.00858 , 0.0102  , ..., 0.004266, 0.007109, 0.00858 ],
#        [0.      , 0.      , 0.      , ..., 0.      , 0.      , 0.      ]])

# %%
ls =  [x for x in os.listdir('./res') if x.startswith('c') and x.endswith('.txt') ]
for x in ls:
    contur_plot('res/'+x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-9c6a2fd9a7f9> in <module>
#       1 ls =  [x for x in os.listdir('./res') if x.startswith('c') and x.endswith('.txt') ]
#       2 for x in ls:
# ----> 3     contur_plot('res/'+x)
#
# <ipython-input-4-f17c01cddde8> in contur_plot(name, C0)
#       5     NX=(NY-1)*2+1
#       6
# ----> 7     z = data.T[2].reshape((NY, NX))
#       8     z-=C0
#       9     x = np.linspace(0, 2.0, NX)
#
# ValueError: cannot reshape array of size 8385 into shape (33,65)

# %%
#%matplotlib notebook

# %%
contur_plot('c.txt')
# Out:
# array([[30.501257, 30.496653, 30.502945, ..., 30.511336, 30.501257,
#         30.496653],
#        [30.590656, 30.478181, 30.443891, ..., 30.531894, 30.590656,
#         30.478181],
#        [30.456308, 30.337564, 30.190249, ..., 30.549365, 30.456308,
#         30.337564],
#        ...,
#        [29.819347, 29.793386, 29.866781, ..., 29.872907, 29.819347,
#         29.793386],
#        [29.751956, 29.695511, 29.710285, ..., 29.773489, 29.751956,
#         29.695511],
#        [29.563204, 29.525066, 29.528522, ..., 29.568855, 29.563204,
#         29.525066]])

# %%
omega = [
    (1.65,1.1900e1,9.8500e1),
    (1.7,1.2011e1,9.3000e1),
    (1.8,1.4032e1,7.9000e1),
    (1.75,1.2385e1,8.7000e1),
    (1.60,1.1914e1,1.0300e2)
    

    
]

# %%
p = np.array(omega).T
plt.plot(p[0],p[1],' o')

# %%
df = pd.read_csv('foo.csv')

# %%
df.plot('t','psi_l')
# Out:
# <AxesSubplot:xlabel='t'>

# %%
df|
# Out:
#   File "<ipython-input-15-4edb420210a5>", line 1
#     df|
#        ^
# SyntaxError: invalid syntax
